# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import re
import warnings 
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.metrics import  (accuracy_score,precision_score,recall_score,f1_score,classification_report,ConfusionMatrixDisplay)

import tensorflow as tf
from tensorflow.keras.layers import(Embedding,SimpleRNN,LSTM,GRU,Bidirectional,Dense,Dropout,SpatialDropout1D)
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.callbacks import (EarlyStopping,ReduceLROnPlateau,ModelCheckpoint)
import  pickle

# %% [markdown]
# ## IMPORT DATASET

# %%
df1=pd.read_json("Sarcasm_Headlines_Dataset_v2.json",lines=True)

# %%
df1.head()
# Out:
#    is_sarcastic                                           headline  \
# 0             1  thirtysomething scientists unveil doomsday clo...
# 1             0  dem rep. totally nails why congress is falling...
# 2             0  eat your veggies: 9 deliciously different recipes
# 3             1  inclement weather prevents liar from getting t...
# 4             1  mother comes pretty close to using word 'strea...
#
#                                         article_link
# 0  https://www.theonion.com/thirtysomething-scien...
# 1  https://www.huffingtonpost.com/entry/donna-edw...
# 2  https://www.huffingtonpost.com/entry/eat-your-...
# 3  https://local.theonion.com/inclement-weather-p...
# 4  https://www.theonion.com/mother-comes-pretty-c...

# %%
df1.duplicated().sum()
# Out:
# np.int64(2)

# %%
df1["headline"].duplicated().sum()
# Out:
# np.int64(116)

# %%
df1.drop_duplicates(subset="headline",inplace=True)

# %%
df1.isnull().sum()
# Out:
# is_sarcastic    0
# headline        0
# article_link    0
# dtype: int64

# %% [markdown]
# ## TEXT CLEANING MINIMAL (  FOR DEEP LEARNING )

# %%
def clean_text(text):
    text= str(text).lower()

    #remove URL
    text = re.sub(r"http\S+|www\S+", "", text)

    # Remove HTML tags
    text = re.sub(r"<.*?>", "", text)

    # Remove extra whitespace
    text = re.sub(r"\s+", " ", text).strip()

    return text

# %%
df1["clean_text"]=df1["headline"].apply(clean_text)

# %%
df1[["headline","clean_text"]].head(10)
# Out:
#                                             headline  \
# 0  thirtysomething scientists unveil doomsday clo...
# 1  dem rep. totally nails why congress is falling...
# 2  eat your veggies: 9 deliciously different recipes
# 3  inclement weather prevents liar from getting t...
# 4  mother comes pretty close to using word 'strea...
# 5                               my white inheritance
# 6         5 ways to file your taxes with less stress
# 7  richard branson's global-warming donation near...
# 8  shadow government getting too large to meet in...
# 9                 lots of parents know this scenario
#
#                                           clean_text
# 0  thirtysomething scientists unveil doomsday clo...
# 1  dem rep. totally nails why congress is falling...
# 2  eat your veggies: 9 deliciously different recipes
# 3  inclement weather prevents liar from getting t...
# 4  mother comes pretty close to using word 'strea...
# 5                               my white inheritance
# 6         5 ways to file your taxes with less stress
# 7  richard branson's global-warming donation near...
# 8  shadow government getting too large to meet in...
# 9                 lots of parents know this scenario

# %% [markdown]
# ## DEFINE X AND Y

# %%
X=df1["clean_text"]
y=df1["is_sarcastic"]

# %%
print("X_shape",X.shape)
print("y_shape:",y.shape)
# Out:
# X_shape (28503,)
# y_shape: (28503,)

# %%
## TRAIN TEST SPLIT

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,stratify=y,random_state=42)

# %%
print("Training Samples:",len(X_train))
print("Testing Samples",len(X_test))
# Out:
# Training Samples: 22802
# Testing Samples 5701

# %%
print(y_test.value_counts())
# Out:
# is_sarcastic
# 0    2990
# 1    2711
# Name: count, dtype: int64

# %% [markdown]
# ## TOKENIZATION

# %%
MAX_WORDS=25000
OOV_TOKEN="<OOV>"

# %%
tokenizer=Tokenizer(num_words=MAX_WORDS,oov_token=OOV_TOKEN)

# %%
tokenizer.fit_on_texts(X_train)

# %%
len(tokenizer.word_index)
# Out:
# 27642

# %%
list(tokenizer.word_index.items())[-50:]
# Out:
# [("92'", 27593),
#  ('rodney', 27594),
#  ('bungles', 27595),
#  ('depends', 27596),
#  ('1996', 27597),
#  ('reintegration', 27598),
#  ('mumolo', 27599),
#  ("'bridesmaids'", 27600),
#  ("'shithole'", 27601),
#  ('tarot', 27602),
#  ('pliers', 27603),
#  ("present's", 27604),
#  ("rogers'", 27605),
#  ('gerrymandered', 27606),
#  ('jubilee', 27607),
#  ('strata', 27608),
#  ('merchandise', 27609),
#  ("'hold", 27610),
#  ('swinging', 27611),
#  ('258', 27612),
#  ('159', 27613),
#  ('mirena', 27614),
#  ('intrauterine', 27615),
#  ('shredder', 27616),
#  ("'suppressed", 27617),
#  ("naked'", 27618),
#  ('weirder', 27619),
#  ('col', 27620),
#  ('samsonite', 27621),
#  ('lint', 27622),
#  ('cardigan', 27623),
#  ('admin', 27624),
#  ('popped', 27625),
#  ('phat', 27626),
#  ('jncos', 27627),
#  ('riley', 27628),
#  ('imagery', 27629),
#  ('stitched', 27630),
#  ("wino's", 27631),
#  ('bronco', 27632),
#  ('forgetful', 27633),
#  ('respecting', 27634),
#  ('thinner', 27635),
#  ('401k', 27636),
#  ("rex's", 27637),
#  ('rotund', 27638),
#  ('replaceable', 27639),
#  ("dream'", 27640),
#  ('weiwei', 27641),
#  ('commemorates', 27642)]

# %%
X_train.apply(type).value_counts()
# Out:
# clean_text
# <class 'str'>    22802
# Name: count, dtype: int64

# %% [markdown]
# ## Convert Text to Sequence

# %%
X_train_seq = tokenizer.texts_to_sequences(X_train)

X_test_seq = tokenizer.texts_to_sequences(X_test)

# %%
print([X_train.iloc[0],X_train_seq[0]])
# Out:
# ["'gobbler games' is the brutal hunger games parody you need to see", [14011, 5450, 11, 4, 4223, 2599, 1486, 2600, 20, 167, 2, 178]]

# %%
# analyze sequence length before max_len

# %%
seq_analyze=[len(sequence) for sequence in X_train_seq]
max(seq_analyze)
# Out:
# 152

# %%
min(seq_analyze)
# Out:
# 2

# %%
pd.Series(seq_analyze).describe(percentiles=[0.90,0.95,0.99])
# Out:
# count    22802.000000
# mean        10.269275
# std          3.445533
# min          2.000000
# 50%         10.000000
# 90%         14.000000
# 95%         16.000000
# 99%         19.000000
# max        152.000000
# dtype: float64

# %%
plt.hist( seq_analyze,bins=40)
plt.show()

# %%
MAX_LEN= int(np.percentile(seq_analyze,95))
MAX_LEN
# Out:
# 16

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
# PADDING
X_train_pad=pad_sequences(X_train_seq,maxlen=MAX_LEN,padding="post",truncating="post")
X_test_pad=pad_sequences(X_test_seq,maxlen=MAX_LEN,padding="post",truncating="post")

# %%
# check shape after padding 
print("Train_shape",X_train_pad.shape)
print("Test Shape",X_test_pad.shape)
# Out:
# Train_shape (22802, 16)
# Test Shape (5701, 16)

# %% [markdown]
# ## Define EVALUATION FUNCTION

# %%
results2=[]

def evaluation_model(model,model_name,x_test,x_train,y_test,y_train,thersold=0.5):
    # predict probablities
    y_prob_test=model.predict(x_test,verbose=0).ravel()
    y_prob_train=model.predict(x_train,verbose=0).ravel()
    

    #convert probablities into labels
    y_pred_test=(y_prob_test>=thersold).astype(int)
    y_pred_train=(y_prob_train>=thersold).astype(int)

    #claculate metrics
    accuracy_test=accuracy_score(y_test,y_pred_test)
    accuracy_train=accuracy_score(y_train,y_pred_train)

    #recall
    recall=recall_score(y_test,y_pred_test,zero_division=0)

    print( f"MODEL :{model_name}")
    print(f"TEST_ACCURACY:{accuracy_test:.4f}")
    print(f"TRAIN_ACCURACY:{accuracy_train:.4f}")
    print(f"RECALL :{recall:.4f}")

    print("\nClassification_Report\n")
    print(classification_report(y_test,y_pred_test,digits=4,zero_division=0))

    # confusion matrix display 
    ConfusionMatrixDisplay.from_predictions(y_test,y_pred_test,cmap="Blues")
    plt.title(f"Confusion Matrix :{model_name}")
    plt.show()

    return { "Model":model_name,"Train_accuracy":accuracy_train,"Test_Accuracy":accuracy_test,"Recall":recall}

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Embedding,SpatialDropout1D,SimpleRNN,Dense,Dropout)

# %% [markdown]
# ## MODELLING

# %% [markdown]
# #### 1.  SIMPLE RNN

# %%
rnn_model= Sequential()

#EMBEDDING
rnn_model.add(Embedding(input_dim= MAX_WORDS,output_dim=128,mask_zero=True))

#Spatial Dropout
rnn_model.add(SpatialDropout1D(0.2))

#SimpleRNN
rnn_model.add(SimpleRNN(units=64,dropout=0.2,recurrent_dropout=0.2))

#Dense Layer
rnn_model.add(Dense(units=64,activation="relu"))

#DROPOUT
rnn_model.add(Dropout(0.2))

#OUTPUT LAYER 
rnn_model.add(Dense(units=1,activation="sigmoid"))

# %%
rnn_model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
rnn_model.build(input_shape=(None,MAX_LEN))
rnn_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 16, 128)        │     3,200,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout1d               │ (None, 16, 128)        │             0 │
# │ (SpatialDropout1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,216,577 (12.27 MB)
#  Trainable params: 3,216,577 (12.27 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#model train 
rnn_history=rnn_model.fit(X_train_pad,y_train,validation_split=0.2,epochs=15,batch_size=64,verbose=1)
# Out:
# Epoch 1/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.7549 - loss: 0.4987 - val_accuracy: 0.8395 - val_loss: 0.3609
# Epoch 2/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 39ms/step - accuracy: 0.8991 - loss: 0.2695 - val_accuracy: 0.8505 - val_loss: 0.3757
# Epoch 3/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 24s 49ms/step - accuracy: 0.9489 - loss: 0.1461 - val_accuracy: 0.8393 - val_loss: 0.4388
# Epoch 4/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 16s 56ms/step - accuracy: 0.9690 - loss: 0.0914 - val_accuracy: 0.8345 - val_loss: 0.5432
# Epoch 5/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 52ms/step - accuracy: 0.9831 - loss: 0.0500 - val_accuracy: 0.8329 - val_loss: 0.6623
# Epoch 6/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 12s 42ms/step - accuracy: 0.9879 - loss: 0.0351 - val_accuracy: 0.8283 - val_loss: 0.7870
# Epoch 7/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9908 - loss: 0.0260 - val_accuracy: 0.8196 - val_loss: 0.7931
# Epoch 8/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 13s 45ms/step - accuracy: 0.9927 - loss: 0.0221 - val_accuracy: 0.8259 - val_loss: 0.9091
# Epoch 9/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 17s 59ms/step - accuracy: 0.9926 - loss: 0.0211 - val_accuracy: 0.8075 - val_loss: 0.7564
# Epoch 10/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 17s 60ms/step - accuracy: 0.9935 - loss: 0.0197 - val_accuracy: 0.8213 - val_loss: 0.9199
# Epoch 11/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 21s 62ms/step - accuracy: 0.9933 - loss: 0.0182 - val_accuracy: 0.8156 - val_loss: 0.8593
# Epoch 12/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 63ms/step - accuracy: 0.9958 - loss: 0.0126 - val_accuracy: 0.8314 - val_loss: 1.0110
# Epoch 13/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 58ms/step - accuracy: 0.9962 - loss: 0.0109 - val_accuracy: 0.8198 - val_loss: 0.9533
# Epoch 14/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 64ms/step - accuracy: 0.9963 - loss: 0.0109 - val_accuracy: 0.8176 - val_loss: 1.0280
# Epoch 15/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 61ms/step - accuracy: 0.9963 - loss: 0.0113 - val_accuracy: 0.8231 - val_loss: 1.0247

# %%
rnn_results=evaluation_model(rnn_model,"Simple-RNN",X_test_pad,X_train_pad,y_test,y_train)
results2.append(rnn_results)
# Out:
# MODEL :Simple-RNN
# TEST_ACCURACY:0.8311
# TRAIN_ACCURACY:0.9644
# RECALL :0.8156
#
# Classification_Report
#
#               precision    recall  f1-score   support
#
#            0     0.8348    0.8452    0.8400      2990
#            1     0.8269    0.8156    0.8212      2711
#
#     accuracy                         0.8311      5701
#    macro avg     0.8308    0.8304    0.8306      5701
# weighted avg     0.8310    0.8311    0.8310      5701

# %%
#Training Accurcay VS VALIDATION ACCURACY GRAPH
plt.figure(figsize=(8, 5))

plt.plot(rnn_history.history["accuracy"],label="Training Accuracy")
plt.plot(rnn_history.history["val_accuracy"],label="Validation Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.title("Simple RNN - Training vs Validation Accuracy")

plt.legend()
plt.grid()

plt.show()

# %%
#Training LOSS VS VALIDATION LOSS GRAPH 

plt.figure(figsize=(8,5))

plt.plot(rnn_history.history["loss"],label="Training_Loss")
plt.plot(rnn_history.history["val_loss"],label="Validation_loss")
plt.xlabel("Epoch")
plt.ylabel("loss")
plt.title("SIMPLE RNN-TRAINING LOSS VS VALIDATION LOSS")
plt.legend()
plt.grid()
plt.show()

# %%
from tensorflow.keras.layers import Input

# %% [markdown]
# #### 2.LSTM

# %%
lstm_model=Sequential()
# Input
lstm_model.add(Input(shape=(MAX_LEN,)))

# embedding 
lstm_model.add(Embedding(input_dim=MAX_WORDS,output_dim=128,mask_zero=True))

# Dropout
lstm_model.add(SpatialDropout1D(0.2))

#LSTM MODEL
lstm_model.add(LSTM(units=64,dropout=0.2,recurrent_dropout=0.2))

#Hidden Layer
lstm_model.add(Dense(units=64,activation='relu'))

#Dropout
lstm_model.add(Dropout(0.3))

# Output Layer
lstm_model.add(Dense(units=1,activation='sigmoid'))

# %%
lstm_model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
lstm_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 16, 128)        │     3,200,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout1d_1             │ (None, 16, 128)        │             0 │
# │ (SpatialDropout1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,253,633 (12.41 MB)
#  Trainable params: 3,253,633 (12.41 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
lstm_history=lstm_model.fit(X_train_pad,y_train,validation_split=0.2,epochs=20,batch_size=64,verbose=1)
# Out:
# Epoch 1/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 54s 97ms/step - accuracy: 0.7918 - loss: 0.4361 - val_accuracy: 0.8529 - val_loss: 0.3442
# Epoch 2/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 21s 75ms/step - accuracy: 0.9254 - loss: 0.1964 - val_accuracy: 0.8463 - val_loss: 0.3619
# Epoch 3/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 44s 85ms/step - accuracy: 0.9694 - loss: 0.0877 - val_accuracy: 0.8356 - val_loss: 0.4851
# Epoch 4/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 40s 80ms/step - accuracy: 0.9878 - loss: 0.0380 - val_accuracy: 0.8342 - val_loss: 0.6483
# Epoch 5/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 39s 71ms/step - accuracy: 0.9922 - loss: 0.0227 - val_accuracy: 0.8338 - val_loss: 0.8406
# Epoch 6/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 103ms/step - accuracy: 0.9950 - loss: 0.0155 - val_accuracy: 0.8336 - val_loss: 0.7852
# Epoch 7/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 33s 73ms/step - accuracy: 0.9962 - loss: 0.0111 - val_accuracy: 0.8340 - val_loss: 0.8781
# Epoch 8/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 100ms/step - accuracy: 0.9966 - loss: 0.0108 - val_accuracy: 0.8292 - val_loss: 0.8879
# Epoch 9/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 32s 110ms/step - accuracy: 0.9980 - loss: 0.0066 - val_accuracy: 0.8253 - val_loss: 1.0120
# Epoch 10/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 30s 71ms/step - accuracy: 0.9974 - loss: 0.0070 - val_accuracy: 0.8242 - val_loss: 1.0406
# Epoch 11/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 79ms/step - accuracy: 0.9985 - loss: 0.0045 - val_accuracy: 0.8209 - val_loss: 1.0303
# Epoch 12/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 47s 100ms/step - accuracy: 0.9977 - loss: 0.0072 - val_accuracy: 0.8281 - val_loss: 1.0902
# Epoch 13/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 80ms/step - accuracy: 0.9984 - loss: 0.0062 - val_accuracy: 0.8257 - val_loss: 1.1188
# Epoch 14/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 80ms/step - accuracy: 0.9982 - loss: 0.0048 - val_accuracy: 0.8209 - val_loss: 1.1078
# Epoch 15/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 37s 65ms/step - accuracy: 0.9996 - loss: 0.0016 - val_accuracy: 0.8259 - val_loss: 1.3572
# Epoch 16/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 68ms/step - accuracy: 0.9991 - loss: 0.0030 - val_accuracy: 0.8248 - val_loss: 1.3956
# Epoch 17/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 65ms/step - accuracy: 0.9987 - loss: 0.0039 - val_accuracy: 0.8220 - val_loss: 1.2931
# Epoch 18/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 66ms/step - accuracy: 0.9986 - loss: 0.0037 - val_accuracy: 0.8191 - val_loss: 1.1881
# Epoch 19/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 64ms/step - accuracy: 0.9992 - loss: 0.0025 - val_accuracy: 0.8150 - val_loss: 1.2695
# Epoch 20/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 67ms/step - accuracy: 0.9993 - loss: 0.0031 - val_accuracy: 0.8272 - val_loss: 1.5046

# %%
lstm_result=evaluation_model(lstm_model,"Simple-LSTM",X_test_pad,X_train_pad,y_test,y_train)
results2.append(lstm_result)
# Out:
# MODEL :Simple-LSTM
# TEST_ACCURACY:0.8337
# TRAIN_ACCURACY:0.9653
# RECALL :0.8458
#
# Classification_Report
#
#               precision    recall  f1-score   support
#
#            0     0.8548    0.8227    0.8384      2990
#            1     0.8123    0.8458    0.8287      2711
#
#     accuracy                         0.8337      5701
#    macro avg     0.8335    0.8343    0.8336      5701
# weighted avg     0.8345    0.8337    0.8338      5701

# %%
#Training Accurcay VS VALIDATION ACCURACY GRAPH
plt.figure(figsize=(8, 5))

plt.plot(lstm_history.history["accuracy"],label="Training Accuracy")
plt.plot(lstm_history.history["val_accuracy"],label="Validation Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.title("LSTM - Training vs Validation Accuracy")

plt.legend()
plt.grid()

plt.show()

# %%
#Training loss VS VALIDATION loss GRAPH 

plt.figure(figsize=(8,5))

plt.plot(rnn_history.history["loss"],label="Training_Loss")
plt.plot(rnn_history.history["val_loss"],label="Validation_loss")
plt.xlabel("Epoch")
plt.ylabel("loss")
plt.title("SIMPLE RNN-TRAINING LOSS VS VALIDATION LOSS")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### 3. GRU

# %%
#Sequential
gru_model=Sequential()

#Input 
gru_model.add(Input(shape=(MAX_LEN,)))

#Embedding Layer
gru_model.add(Embedding(input_dim=MAX_WORDS,output_dim=128,mask_zero=True))

#dropout layer
gru_model.add(SpatialDropout1D(0.2))

#Model
gru_model.add(GRU(units=64,dropout=0.2,recurrent_dropout=0.3))

#Hidden Layer
gru_model.add(Dense(units=64,activation='relu'))

#Dropout
gru_model.add(Dropout(0.3))

# Output

gru_model.add(Dense(units=1,activation='sigmoid'))

# %%
gru_model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
gru_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 16, 128)        │     3,200,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout1d_2             │ (None, 16, 128)        │             0 │
# │ (SpatialDropout1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 64)             │        37,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,241,473 (12.37 MB)
#  Trainable params: 3,241,473 (12.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
gru_history=gru_model.fit(X_train_pad,y_train,validation_split=0.2,epochs=20,batch_size=64,verbose=1)
# Out:
# Epoch 1/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 34s 71ms/step - accuracy: 0.7625 - loss: 0.4635 - val_accuracy: 0.8485 - val_loss: 0.3446
# Epoch 2/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 16s 56ms/step - accuracy: 0.9189 - loss: 0.2151 - val_accuracy: 0.8474 - val_loss: 0.3548
# Epoch 3/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 68ms/step - accuracy: 0.9641 - loss: 0.1032 - val_accuracy: 0.8421 - val_loss: 0.4714
# Epoch 4/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 64ms/step - accuracy: 0.9832 - loss: 0.0474 - val_accuracy: 0.8318 - val_loss: 0.5369
# Epoch 5/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - accuracy: 0.9918 - loss: 0.0274 - val_accuracy: 0.8285 - val_loss: 0.7073
# Epoch 6/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 37s 58ms/step - accuracy: 0.9939 - loss: 0.0171 - val_accuracy: 0.8310 - val_loss: 0.7626
# Epoch 7/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9956 - loss: 0.0144 - val_accuracy: 0.8292 - val_loss: 0.8956
# Epoch 8/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step - accuracy: 0.9971 - loss: 0.0078 - val_accuracy: 0.8246 - val_loss: 0.9516
# Epoch 9/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step - accuracy: 0.9987 - loss: 0.0042 - val_accuracy: 0.8305 - val_loss: 1.1379
# Epoch 10/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step - accuracy: 0.9974 - loss: 0.0086 - val_accuracy: 0.8266 - val_loss: 1.0160
# Epoch 11/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step - accuracy: 0.9974 - loss: 0.0072 - val_accuracy: 0.8150 - val_loss: 1.0515
# Epoch 12/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 52ms/step - accuracy: 0.9979 - loss: 0.0059 - val_accuracy: 0.8189 - val_loss: 1.0775
# Epoch 13/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 52ms/step - accuracy: 0.9981 - loss: 0.0063 - val_accuracy: 0.8233 - val_loss: 1.1124
# Epoch 14/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 52ms/step - accuracy: 0.9993 - loss: 0.0024 - val_accuracy: 0.8220 - val_loss: 1.2018
# Epoch 15/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 16s 54ms/step - accuracy: 0.9987 - loss: 0.0034 - val_accuracy: 0.8174 - val_loss: 1.2373
# Epoch 16/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 16s 54ms/step - accuracy: 0.9987 - loss: 0.0038 - val_accuracy: 0.8202 - val_loss: 1.2687
# Epoch 17/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 54ms/step - accuracy: 0.9986 - loss: 0.0044 - val_accuracy: 0.8209 - val_loss: 1.3255
# Epoch 18/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 16s 55ms/step - accuracy: 0.9987 - loss: 0.0039 - val_accuracy: 0.8176 - val_loss: 1.1896
# Epoch 19/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 16s 54ms/step - accuracy: 0.9988 - loss: 0.0030 - val_accuracy: 0.8207 - val_loss: 1.2526
# Epoch 20/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 53ms/step - accuracy: 0.9989 - loss: 0.0041 - val_accuracy: 0.8224 - val_loss: 1.2258

# %%
gru_result=evaluation_model(gru_model,"Simple-GRU",X_test_pad,X_train_pad,y_test,y_train)
results2.append(gru_result)
# Out:
# MODEL :Simple-GRU
# TEST_ACCURACY:0.8297
# TRAIN_ACCURACY:0.9644
# RECALL :0.8115
#
# Classification_Report
#
#               precision    recall  f1-score   support
#
#            0     0.8320    0.8462    0.8390      2990
#            1     0.8271    0.8115    0.8192      2711
#
#     accuracy                         0.8297      5701
#    macro avg     0.8295    0.8288    0.8291      5701
# weighted avg     0.8296    0.8297    0.8296      5701

# %%
#Training Accurcay VS VALIDATION ACCURACY GRAPH
plt.figure(figsize=(8, 5))

plt.plot(gru_history.history["accuracy"],label="Training Accuracy")
plt.plot(gru_history.history["val_accuracy"],label="Validation Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.title("LSTM - Training vs Validation Accuracy")

plt.legend()
plt.grid()

plt.show()

# %%
#Training loss VS VALIDATION loss GRAPH 

plt.figure(figsize=(8,5))

plt.plot(gru_history.history["loss"],label="Training_Loss")
plt.plot(gru_history.history["val_loss"],label="Validation_loss")
plt.xlabel("Epoch")
plt.ylabel("loss")
plt.title("SIMPLE RNN-TRAINING LOSS VS VALIDATION LOSS")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### 4. BI DIRECTIONAL RNN

# %%
birnn_model=Sequential()

#Input 
birnn_model.add(Input(shape=(MAX_LEN,)))

# Embedding
birnn_model.add(Embedding(input_dim=MAX_WORDS,output_dim=128,mask_zero=True))

#DROPOUT
birnn_model.add(SpatialDropout1D(0.2))

# Model Layer
birnn_model.add(Bidirectional(SimpleRNN(units=64,dropout=0.2,recurrent_dropout=0.3)))

#hidden Layer
birnn_model.add(Dense(units=64,activation='relu'))

#dropout
birnn_model.add(Dropout(0.3))

#output

birnn_model.add(Dense(units=1,activation='sigmoid'))

# %%
birnn_model.compile(optimizer='adam',loss="binary_crossentropy",metrics=["accuracy"])

# %%
birnn_history=birnn_model.fit( X_train_pad,y_train,validation_split=0.2,epochs=20,batch_size=64,verbose=1)
# Out:
# Epoch 1/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 53ms/step - accuracy: 0.6718 - loss: 0.5792 - val_accuracy: 0.8202 - val_loss: 0.3959
# Epoch 2/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.8724 - loss: 0.3139 - val_accuracy: 0.8481 - val_loss: 0.3679
# Epoch 3/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9374 - loss: 0.1717 - val_accuracy: 0.8404 - val_loss: 0.4362
# Epoch 4/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9666 - loss: 0.0981 - val_accuracy: 0.8353 - val_loss: 0.4858
# Epoch 5/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 51ms/step - accuracy: 0.9794 - loss: 0.0616 - val_accuracy: 0.8310 - val_loss: 0.6026
# Epoch 6/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 52ms/step - accuracy: 0.9872 - loss: 0.0389 - val_accuracy: 0.8391 - val_loss: 0.6910
# Epoch 7/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 51ms/step - accuracy: 0.9910 - loss: 0.0244 - val_accuracy: 0.8299 - val_loss: 0.8708
# Epoch 8/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9938 - loss: 0.0177 - val_accuracy: 0.8296 - val_loss: 0.8854
# Epoch 9/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.9937 - loss: 0.0179 - val_accuracy: 0.8345 - val_loss: 0.8308
# Epoch 10/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 63ms/step - accuracy: 0.9952 - loss: 0.0141 - val_accuracy: 0.8349 - val_loss: 0.8244
# Epoch 11/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 16s 57ms/step - accuracy: 0.9954 - loss: 0.0123 - val_accuracy: 0.8347 - val_loss: 0.9701
# Epoch 12/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 16s 55ms/step - accuracy: 0.9962 - loss: 0.0115 - val_accuracy: 0.8356 - val_loss: 1.0003
# Epoch 13/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 52ms/step - accuracy: 0.9973 - loss: 0.0083 - val_accuracy: 0.8362 - val_loss: 1.0459
# Epoch 14/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9978 - loss: 0.0058 - val_accuracy: 0.8272 - val_loss: 1.2850
# Epoch 15/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - accuracy: 0.9978 - loss: 0.0073 - val_accuracy: 0.8327 - val_loss: 1.0580
# Epoch 16/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9961 - loss: 0.0104 - val_accuracy: 0.8264 - val_loss: 1.1073
# Epoch 17/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 54ms/step - accuracy: 0.9954 - loss: 0.0152 - val_accuracy: 0.8244 - val_loss: 0.9437
# Epoch 18/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 16s 54ms/step - accuracy: 0.9970 - loss: 0.0079 - val_accuracy: 0.8246 - val_loss: 1.1811
# Epoch 19/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step - accuracy: 0.9983 - loss: 0.0055 - val_accuracy: 0.8316 - val_loss: 1.1848
# Epoch 20/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 13s 47ms/step - accuracy: 0.9988 - loss: 0.0037 - val_accuracy: 0.8292 - val_loss: 1.1113

# %%
birnn_result=evaluation_model(birnn_model,"BI-RNN",X_test_pad,X_train_pad,y_test,y_train)
results2.append(birnn_result)
# Out:
# MODEL :BI-RNN
# TEST_ACCURACY:0.8372
# TRAIN_ACCURACY:0.9658
# RECALL :0.8292
#
# Classification_Report
#
#               precision    recall  f1-score   support
#
#            0     0.8450    0.8445    0.8448      2990
#            1     0.8286    0.8292    0.8289      2711
#
#     accuracy                         0.8372      5701
#    macro avg     0.8368    0.8368    0.8368      5701
# weighted avg     0.8372    0.8372    0.8372      5701

# %%
#Training Accurcay VS VALIDATION ACCURACY GRAPH
plt.figure(figsize=(8, 5))

plt.plot(birnn_history.history["accuracy"],label="Training Accuracy")
plt.plot(birnn_history.history["val_accuracy"],label="Validation Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.title("BI-RNN - Training vs Validation Accuracy")

plt.legend()
plt.grid()

plt.show()

# %%
#Training loss VS VALIDATION loss GRAPH 

plt.figure(figsize=(8,5))

plt.plot(birnn_history.history["loss"],label="Training_Loss")
plt.plot(birnn_history.history["val_loss"],label="Validation_loss")
plt.xlabel("Epoch")
plt.ylabel("loss")
plt.title("BI RNN-TRAINING LOSS VS VALIDATION LOSS")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### 5. BI-LSTM

# %%
bilstm_model=Sequential()

#Input 
bilstm_model.add(Input(shape=(MAX_LEN,)))

# Embedding
bilstm_model.add(Embedding(input_dim=MAX_WORDS,output_dim=128,mask_zero=True))

#DROPOUT
bilstm_model.add(SpatialDropout1D(0.2))

# Model Layer
bilstm_model.add(Bidirectional(LSTM(units=64,dropout=0.2,recurrent_dropout=0.3)))

#hidden Layer
bilstm_model.add(Dense(units=64,activation='relu'))

#dropout
bilstm_model.add(Dropout(0.3))

#output

bilstm_model.add(Dense(units=1,activation='sigmoid'))

# %%
bilstm_model.compile(optimizer='adam',loss="binary_crossentropy",metrics=["accuracy"])

# %%
bilstm_history=bilstm_model.fit( X_train_pad,y_train,validation_split=0.2,epochs=20,batch_size=64,verbose=1)
# Out:
# Epoch 1/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 39s 81ms/step - accuracy: 0.8054 - loss: 0.4130 - val_accuracy: 0.8478 - val_loss: 0.3432
# Epoch 2/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 22s 75ms/step - accuracy: 0.9322 - loss: 0.1761 - val_accuracy: 0.8511 - val_loss: 0.3472
# Epoch 3/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 21s 75ms/step - accuracy: 0.9741 - loss: 0.0756 - val_accuracy: 0.8421 - val_loss: 0.4466
# Epoch 4/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 70ms/step - accuracy: 0.9909 - loss: 0.0291 - val_accuracy: 0.8380 - val_loss: 0.6099
# Epoch 5/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 68ms/step - accuracy: 0.9955 - loss: 0.0136 - val_accuracy: 0.8336 - val_loss: 0.7557
# Epoch 6/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 21s 72ms/step - accuracy: 0.9959 - loss: 0.0114 - val_accuracy: 0.8349 - val_loss: 0.7812
# Epoch 7/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 41s 71ms/step - accuracy: 0.9969 - loss: 0.0093 - val_accuracy: 0.8342 - val_loss: 0.7870
# Epoch 8/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 70ms/step - accuracy: 0.9982 - loss: 0.0059 - val_accuracy: 0.8406 - val_loss: 0.9403
# Epoch 9/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 71ms/step - accuracy: 0.9979 - loss: 0.0058 - val_accuracy: 0.8358 - val_loss: 1.0016
# Epoch 10/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 21s 72ms/step - accuracy: 0.9984 - loss: 0.0050 - val_accuracy: 0.8321 - val_loss: 0.9150
# Epoch 11/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 22s 75ms/step - accuracy: 0.9992 - loss: 0.0031 - val_accuracy: 0.8332 - val_loss: 1.0686
# Epoch 12/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 21s 72ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 0.8279 - val_loss: 1.0423
# Epoch 13/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 21s 73ms/step - accuracy: 0.9985 - loss: 0.0043 - val_accuracy: 0.8318 - val_loss: 1.1462
# Epoch 14/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 42s 75ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.8345 - val_loss: 1.4440
# Epoch 15/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 21s 72ms/step - accuracy: 0.9985 - loss: 0.0049 - val_accuracy: 0.8250 - val_loss: 1.1059
# Epoch 16/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 21s 73ms/step - accuracy: 0.9992 - loss: 0.0022 - val_accuracy: 0.8292 - val_loss: 1.3665
# Epoch 17/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 22s 76ms/step - accuracy: 0.9990 - loss: 0.0036 - val_accuracy: 0.8294 - val_loss: 1.1789
# Epoch 18/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 21s 74ms/step - accuracy: 0.9995 - loss: 0.0020 - val_accuracy: 0.8272 - val_loss: 1.2931
# Epoch 19/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 22s 77ms/step - accuracy: 0.9993 - loss: 0.0019 - val_accuracy: 0.8167 - val_loss: 1.4788
# Epoch 20/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 23s 79ms/step - accuracy: 0.9987 - loss: 0.0043 - val_accuracy: 0.8237 - val_loss: 1.2094

# %%
bilstm_result=evaluation_model(bilstm_model,"BI-LSTM",X_test_pad,X_train_pad,y_test,y_train)
results2.append(bilstm_result)
# Out:
# MODEL :BI-LSTM
# TEST_ACCURACY:0.8413
# TRAIN_ACCURACY:0.9647
# RECALL :0.8126
#
# Classification_Report
#
#               precision    recall  f1-score   support
#
#            0     0.8362    0.8672    0.8514      2990
#            1     0.8473    0.8126    0.8296      2711
#
#     accuracy                         0.8413      5701
#    macro avg     0.8417    0.8399    0.8405      5701
# weighted avg     0.8415    0.8413    0.8410      5701

# %%
#Training Accurcay VS VALIDATION ACCURACY GRAPH
plt.figure(figsize=(8, 5))

plt.plot(bilstm_history.history["accuracy"],label="Training Accuracy")
plt.plot(bilstm_history.history["val_accuracy"],label="Validation Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.title("BI-LSTM - Training vs Validation Accuracy")

plt.legend()
plt.grid()

plt.show()

# %%
#Training loss VS VALIDATION loss GRAPH 

plt.figure(figsize=(8,5))

plt.plot(bilstm_history.history["loss"],label="Training_Loss")
plt.plot(bilstm_history.history["val_loss"],label="Validation_loss")
plt.xlabel("Epoch")
plt.ylabel("loss")
plt.title("BI RNN-TRAINING LOSS VS VALIDATION LOSS")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### 6. BI-GRU

# %%
bigru_model=Sequential()

#Input 
bigru_model.add(Input(shape=(MAX_LEN,)))

# Embedding
bigru_model.add(Embedding(input_dim=MAX_WORDS,output_dim=128,mask_zero=True))

#DROPOUT
bigru_model.add(SpatialDropout1D(0.2))

# Model Layer
bigru_model.add(Bidirectional(GRU(units=64,dropout=0.2,recurrent_dropout=0.3)))

#hidden Layer
bigru_model.add(Dense(units=64,activation='relu'))

#dropout
bigru_model.add(Dropout(0.3))

#output

bigru_model.add(Dense(units=1,activation='sigmoid'))

# %%
bigru_model.compile(optimizer='adam',loss="binary_crossentropy",metrics=["accuracy"])

# %%
bigru_history=bigru_model.fit( X_train_pad,y_train,validation_split=0.2,epochs=20,batch_size=64,verbose=1)
# Out:
# Epoch 1/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 43s 78ms/step - accuracy: 0.7956 - loss: 0.4144 - val_accuracy: 0.8592 - val_loss: 0.3195
# Epoch 2/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 69ms/step - accuracy: 0.9380 - loss: 0.1640 - val_accuracy: 0.8470 - val_loss: 0.3722
# Epoch 3/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 70ms/step - accuracy: 0.9811 - loss: 0.0570 - val_accuracy: 0.8430 - val_loss: 0.5253
# Epoch 4/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 67ms/step - accuracy: 0.9914 - loss: 0.0251 - val_accuracy: 0.8340 - val_loss: 0.6781
# Epoch 5/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 66ms/step - accuracy: 0.9965 - loss: 0.0103 - val_accuracy: 0.8290 - val_loss: 0.7834
# Epoch 6/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 21s 72ms/step - accuracy: 0.9974 - loss: 0.0086 - val_accuracy: 0.8290 - val_loss: 0.9338
# Epoch 7/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 67ms/step - accuracy: 0.9981 - loss: 0.0056 - val_accuracy: 0.8283 - val_loss: 0.9622
# Epoch 8/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 68ms/step - accuracy: 0.9982 - loss: 0.0055 - val_accuracy: 0.8294 - val_loss: 0.9493
# Epoch 9/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 68ms/step - accuracy: 0.9982 - loss: 0.0042 - val_accuracy: 0.8307 - val_loss: 1.0471
# Epoch 10/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 67ms/step - accuracy: 0.9988 - loss: 0.0034 - val_accuracy: 0.8314 - val_loss: 1.1616
# Epoch 11/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 68ms/step - accuracy: 0.9985 - loss: 0.0048 - val_accuracy: 0.8264 - val_loss: 1.0864
# Epoch 12/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 65ms/step - accuracy: 0.9986 - loss: 0.0038 - val_accuracy: 0.8292 - val_loss: 1.2307
# Epoch 13/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 69ms/step - accuracy: 0.9985 - loss: 0.0049 - val_accuracy: 0.8279 - val_loss: 1.1462
# Epoch 14/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 65ms/step - accuracy: 0.9987 - loss: 0.0045 - val_accuracy: 0.8285 - val_loss: 1.1167
# Epoch 15/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 69ms/step - accuracy: 0.9984 - loss: 0.0043 - val_accuracy: 0.8222 - val_loss: 1.1493
# Epoch 16/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 21s 72ms/step - accuracy: 0.9988 - loss: 0.0036 - val_accuracy: 0.8204 - val_loss: 1.1736
# Epoch 17/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 68ms/step - accuracy: 0.9992 - loss: 0.0022 - val_accuracy: 0.8200 - val_loss: 1.2902
# Epoch 18/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 71ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.8250 - val_loss: 1.3214
# Epoch 19/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 68ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.8207 - val_loss: 1.4621
# Epoch 20/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 22s 76ms/step - accuracy: 0.9996 - loss: 9.6663e-04 - val_accuracy: 0.8226 - val_loss: 1.5318

# %%
bigru_result=evaluation_model(bigru_model,"BI-GRU",X_test_pad,X_train_pad,y_test,y_train)
results2.append(bigru_result)
# Out:
# MODEL :BI-GRU
# TEST_ACCURACY:0.8341
# TRAIN_ACCURACY:0.9645
# RECALL :0.8277
#
# Classification_Report
#
#               precision    recall  f1-score   support
#
#            0     0.8432    0.8398    0.8415      2990
#            1     0.8241    0.8277    0.8259      2711
#
#     accuracy                         0.8341      5701
#    macro avg     0.8336    0.8338    0.8337      5701
# weighted avg     0.8341    0.8341    0.8341      5701

# %%
#Training Accurcay VS VALIDATION ACCURACY GRAPH
plt.figure(figsize=(8, 5))

plt.plot(bigru_history.history["accuracy"],label="Training Accuracy")
plt.plot(bigru_history.history["val_accuracy"],label="Validation Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.title("BI-GRU - Training vs Validation Accuracy")

plt.legend()
plt.grid()

plt.show()

# %%
#Training loss VS VALIDATION loss GRAPH 

plt.figure(figsize=(8,5))

plt.plot(bigru_history.history["loss"],label="Training_Loss")
plt.plot(bigru_history.history["val_loss"],label="Validation_loss")
plt.xlabel("Epoch")
plt.ylabel("loss")
plt.title("BI-GRU-TRAINING LOSS VS VALIDATION LOSS")
plt.legend()
plt.grid()
plt.show()

# %%
r1=pd.DataFrame(results2)
r1
# Out:
#          Model  Train_accuracy  Test_Accuracy    Recall
# 0   Simple-RNN        0.964389       0.831082  0.815566
# 1  Simple-LSTM        0.965266       0.833713  0.845813
# 2   Simple-GRU        0.964433       0.829679  0.811509
# 3       BI-RNN        0.965792       0.837222  0.829214
# 4      BI-LSTM        0.964696       0.841256  0.812615
# 5       BI-GRU        0.964477       0.834064  0.827739
