# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import re
import warnings 
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.metrics import  (accuracy_score,precision_score,recall_score,f1_score,classification_report,ConfusionMatrixDisplay)

import tensorflow as tf
from tensorflow.keras.layers import(Embedding,SimpleRNN,LSTM,GRU,Bidirectional,Dense,Dropout,SpatialDropout1D)
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.callbacks import (EarlyStopping,ReduceLROnPlateau,ModelCheckpoint)
import  pickle

# %% [markdown]
# ## IMPORT DATASET

# %%
df1=pd.read_json("Sarcasm_Headlines_Dataset_v2.json",lines=True)

# %%
df1.head()
# Out:
#    is_sarcastic                                           headline  \
# 0             1  thirtysomething scientists unveil doomsday clo...
# 1             0  dem rep. totally nails why congress is falling...
# 2             0  eat your veggies: 9 deliciously different recipes
# 3             1  inclement weather prevents liar from getting t...
# 4             1  mother comes pretty close to using word 'strea...
#
#                                         article_link
# 0  https://www.theonion.com/thirtysomething-scien...
# 1  https://www.huffingtonpost.com/entry/donna-edw...
# 2  https://www.huffingtonpost.com/entry/eat-your-...
# 3  https://local.theonion.com/inclement-weather-p...
# 4  https://www.theonion.com/mother-comes-pretty-c...

# %%
df1.duplicated().sum()
# Out:
# np.int64(2)

# %%
df1["headline"].duplicated().sum()
# Out:
# np.int64(116)

# %%
df1.drop_duplicates(subset="headline",inplace=True)

# %%
df1.isnull().sum()
# Out:
# is_sarcastic    0
# headline        0
# article_link    0
# dtype: int64

# %% [markdown]
# ## TEXT CLEANING MINIMAL (  FOR DEEP LEARNING )

# %%
def clean_text(text):
    text= str(text).lower()

    #remove URL
    text = re.sub(r"http\S+|www\S+", "", text)

    # Remove HTML tags
    text = re.sub(r"<.*?>", "", text)

    # Remove extra whitespace
    text = re.sub(r"\s+", " ", text).strip()

    return text

# %%
df1["clean_text"]=df1["headline"].apply(clean_text)

# %%
df1[["headline","clean_text"]].head(10)
# Out:
#                                             headline  \
# 0  thirtysomething scientists unveil doomsday clo...
# 1  dem rep. totally nails why congress is falling...
# 2  eat your veggies: 9 deliciously different recipes
# 3  inclement weather prevents liar from getting t...
# 4  mother comes pretty close to using word 'strea...
# 5                               my white inheritance
# 6         5 ways to file your taxes with less stress
# 7  richard branson's global-warming donation near...
# 8  shadow government getting too large to meet in...
# 9                 lots of parents know this scenario
#
#                                           clean_text
# 0  thirtysomething scientists unveil doomsday clo...
# 1  dem rep. totally nails why congress is falling...
# 2  eat your veggies: 9 deliciously different recipes
# 3  inclement weather prevents liar from getting t...
# 4  mother comes pretty close to using word 'strea...
# 5                               my white inheritance
# 6         5 ways to file your taxes with less stress
# 7  richard branson's global-warming donation near...
# 8  shadow government getting too large to meet in...
# 9                 lots of parents know this scenario

# %% [markdown]
# ## DEFINE X AND Y

# %%
X=df1["clean_text"]
y=df1["is_sarcastic"]

# %%
print("X_shape",X.shape)
print("y_shape:",y.shape)
# Out:
# X_shape (28503,)
# y_shape: (28503,)

# %%
## TRAIN TEST SPLIT

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,stratify=y,random_state=42)

# %%
print("Training Samples:",len(X_train))
print("Testing Samples",len(X_test))
# Out:
# Training Samples: 22802
# Testing Samples 5701

# %%
print(y_test.value_counts())
# Out:
# is_sarcastic
# 0    2990
# 1    2711
# Name: count, dtype: int64

# %% [markdown]
# ## TOKENIZATION

# %%
MAX_WORDS=25000
OOV_TOKEN="<OOV>"

# %%
tokenizer=Tokenizer(num_words=MAX_WORDS,oov_token=OOV_TOKEN)

# %%
tokenizer.fit_on_texts(X_train)

# %%
len(tokenizer.word_index)
# Out:
# 27642

# %%
list(tokenizer.word_index.items())[-50:]
# Out:
# [("92'", 27593),
#  ('rodney', 27594),
#  ('bungles', 27595),
#  ('depends', 27596),
#  ('1996', 27597),
#  ('reintegration', 27598),
#  ('mumolo', 27599),
#  ("'bridesmaids'", 27600),
#  ("'shithole'", 27601),
#  ('tarot', 27602),
#  ('pliers', 27603),
#  ("present's", 27604),
#  ("rogers'", 27605),
#  ('gerrymandered', 27606),
#  ('jubilee', 27607),
#  ('strata', 27608),
#  ('merchandise', 27609),
#  ("'hold", 27610),
#  ('swinging', 27611),
#  ('258', 27612),
#  ('159', 27613),
#  ('mirena', 27614),
#  ('intrauterine', 27615),
#  ('shredder', 27616),
#  ("'suppressed", 27617),
#  ("naked'", 27618),
#  ('weirder', 27619),
#  ('col', 27620),
#  ('samsonite', 27621),
#  ('lint', 27622),
#  ('cardigan', 27623),
#  ('admin', 27624),
#  ('popped', 27625),
#  ('phat', 27626),
#  ('jncos', 27627),
#  ('riley', 27628),
#  ('imagery', 27629),
#  ('stitched', 27630),
#  ("wino's", 27631),
#  ('bronco', 27632),
#  ('forgetful', 27633),
#  ('respecting', 27634),
#  ('thinner', 27635),
#  ('401k', 27636),
#  ("rex's", 27637),
#  ('rotund', 27638),
#  ('replaceable', 27639),
#  ("dream'", 27640),
#  ('weiwei', 27641),
#  ('commemorates', 27642)]

# %%
X_train.apply(type).value_counts()
# Out:
# clean_text
# <class 'str'>    22802
# Name: count, dtype: int64

# %% [markdown]
# ## Convert Text to Sequence

# %%
X_train_seq = tokenizer.texts_to_sequences(X_train)

X_test_seq = tokenizer.texts_to_sequences(X_test)

# %%
print([X_train.iloc[0],X_train_seq[0]])
# Out:
# ["'gobbler games' is the brutal hunger games parody you need to see", [14011, 5450, 11, 4, 4223, 2599, 1486, 2600, 20, 167, 2, 178]]

# %%
# analyze sequence length before max_len

# %%
seq_analyze=[len(sequence) for sequence in X_train_seq]
max(seq_analyze)
# Out:
# 152

# %%
min(seq_analyze)
# Out:
# 2

# %%
pd.Series(seq_analyze).describe(percentiles=[0.90,0.95,0.99])
# Out:
# count    22802.000000
# mean        10.269275
# std          3.445533
# min          2.000000
# 50%         10.000000
# 90%         14.000000
# 95%         16.000000
# 99%         19.000000
# max        152.000000
# dtype: float64

# %%
plt.hist( seq_analyze,bins=40)
plt.show()

# %%
MAX_LEN= int(np.percentile(seq_analyze,95))
MAX_LEN
# Out:
# 16

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
# PADDING
X_train_pad=pad_sequences(X_train_seq,maxlen=MAX_LEN,padding="post",truncating="post")
X_test_pad=pad_sequences(X_test_seq,maxlen=MAX_LEN,padding="post",truncating="post")

# %%
# check shape after padding 
print("Train_shape",X_train_pad.shape)
print("Test Shape",X_test_pad.shape)
# Out:
# Train_shape (22802, 16)
# Test Shape (5701, 16)

# %% [markdown]
# ## Define EVALUATION FUNCTION

# %%
results1=[]

def evaluation_model(model,model_name,x_test,x_train,y_test,y_train,thersold=0.5):
    # predict probablities
    y_prob_test=model.predict(x_test,verbose=0).ravel()
    y_prob_train=model.predict(x_train,verbose=0).ravel()
    

    #convert probablities into labels
    y_pred_test=(y_prob_test>=thersold).astype(int)
    y_pred_train=(y_prob_train>=thersold).astype(int)

    #claculate metrics
    accuracy_test=accuracy_score(y_test,y_pred_test)
    accuracy_train=accuracy_score(y_train,y_pred_train)

    #recall
    recall=recall_score(y_test,y_pred_test,zero_division=0)

    print( f"MODEL :{model_name}")
    print(f"TEST_ACCURACY:{accuracy_test:.4f}")
    print(f"TRAIN_ACCURACY:{accuracy_train:.4f}")
    print(f"RECALL :{recall:.4f}")

    print("\nClassification_Report\n")
    print(classification_report(y_test,y_pred_test,digits=4,zero_division=0))

    # confusion matrix display 
    ConfusionMatrixDisplay.from_predictions(y_test,y_pred_test,cmap="Blues")
    plt.title(f"Confusion Matrix :{model_name}")
    plt.show()

    return { "Model":model_name,"Train_accuracy":accuracy_train,"Test_Accuracy":accuracy_test,"Recall":recall}

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Embedding,SpatialDropout1D,SimpleRNN,Dense,Dropout)

# %% [markdown]
# ## MODELLING

# %% [markdown]
# #### 1.  SIMPLE RNN

# %%
rnn_model= Sequential()

#EMBEDDING
rnn_model.add(Embedding(input_dim= MAX_WORDS,output_dim=128,mask_zero=True))

#Spatial Dropout
rnn_model.add(SpatialDropout1D(0.2))

#SimpleRNN
rnn_model.add(SimpleRNN(units=64,dropout=0.2,recurrent_dropout=0.2))

#Dense Layer
rnn_model.add(Dense(units=64,activation="relu"))

#DROPOUT
rnn_model.add(Dropout(0.2))

#OUTPUT LAYER 
rnn_model.add(Dense(units=1,activation="sigmoid"))

# %%
rnn_model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
rnn_model.build(input_shape=(None,MAX_LEN))
rnn_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 16, 128)        │     3,200,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout1d               │ (None, 16, 128)        │             0 │
# │ (SpatialDropout1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,216,577 (12.27 MB)
#  Trainable params: 3,216,577 (12.27 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#model train 
rnn_history=rnn_model.fit(X_train_pad,y_train,validation_split=0.2,epochs=15,batch_size=64,verbose=1)
# Out:
# Epoch 1/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 16s 44ms/step - accuracy: 0.7373 - loss: 0.5220 - val_accuracy: 0.8156 - val_loss: 0.4217
# Epoch 2/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 13s 45ms/step - accuracy: 0.8925 - loss: 0.2789 - val_accuracy: 0.8476 - val_loss: 0.3710
# Epoch 3/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 12s 42ms/step - accuracy: 0.9500 - loss: 0.1489 - val_accuracy: 0.8408 - val_loss: 0.4362
# Epoch 4/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - accuracy: 0.9739 - loss: 0.0773 - val_accuracy: 0.8222 - val_loss: 0.4982
# Epoch 5/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.9789 - loss: 0.0618 - val_accuracy: 0.8334 - val_loss: 0.6073
# Epoch 6/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 13s 44ms/step - accuracy: 0.9872 - loss: 0.0382 - val_accuracy: 0.8226 - val_loss: 0.6863
# Epoch 7/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 12s 44ms/step - accuracy: 0.9923 - loss: 0.0231 - val_accuracy: 0.8244 - val_loss: 0.7974
# Epoch 8/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 13s 44ms/step - accuracy: 0.9933 - loss: 0.0207 - val_accuracy: 0.8338 - val_loss: 0.9158
# Epoch 9/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 12s 42ms/step - accuracy: 0.9938 - loss: 0.0181 - val_accuracy: 0.8215 - val_loss: 0.8366
# Epoch 10/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 12s 42ms/step - accuracy: 0.9944 - loss: 0.0170 - val_accuracy: 0.8180 - val_loss: 0.8412
# Epoch 11/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 12s 42ms/step - accuracy: 0.9951 - loss: 0.0140 - val_accuracy: 0.8176 - val_loss: 0.8817
# Epoch 12/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 39ms/step - accuracy: 0.9954 - loss: 0.0126 - val_accuracy: 0.8237 - val_loss: 1.0176
# Epoch 13/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - accuracy: 0.9954 - loss: 0.0139 - val_accuracy: 0.8204 - val_loss: 0.9466
# Epoch 14/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 40ms/step - accuracy: 0.9963 - loss: 0.0108 - val_accuracy: 0.8117 - val_loss: 1.0766
# Epoch 15/15
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - accuracy: 0.9964 - loss: 0.0111 - val_accuracy: 0.8226 - val_loss: 0.9540

# %%
rnn_results=evaluation_model(rnn_model,"Simple-RNN",X_test_pad,X_train_pad,y_test,y_train)
results1.append(rnn_results)
# Out:
# MODEL :Simple-RNN
# TEST_ACCURACY:0.8330
# TRAIN_ACCURACY:0.9641
# RECALL :0.8340
#
# Classification_Report
#
#               precision    recall  f1-score   support
#
#            0     0.8468    0.8321    0.8394      2990
#            1     0.8183    0.8340    0.8261      2711
#
#     accuracy                         0.8330      5701
#    macro avg     0.8326    0.8331    0.8327      5701
# weighted avg     0.8333    0.8330    0.8331      5701

# %%
#Training Accurcay VS VALIDATION ACCURACY GRAPH
plt.figure(figsize=(8, 5))

plt.plot(rnn_history.history["accuracy"],label="Training Accuracy")
plt.plot(rnn_history.history["val_accuracy"],label="Validation Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.title("Simple RNN - Training vs Validation Accuracy")

plt.legend()
plt.grid()

plt.show()

# %%
#Training LOSS VS VALIDATION LOSS GRAPH 

plt.figure(figsize=(8,5))

plt.plot(rnn_history.history["loss"],label="Training_Loss")
plt.plot(rnn_history.history["val_loss"],label="Validation_loss")
plt.xlabel("Epoch")
plt.ylabel("loss")
plt.title("SIMPLE RNN-TRAINING LOSS VS VALIDATION LOSS")
plt.legend()
plt.grid()
plt.show()

# %%
from tensorflow.keras.layers import Input

# %% [markdown]
# #### 2.LSTM

# %%
lstm_model=Sequential()
# Input
lstm_model.add(Input(shape=(MAX_LEN,)))

# embedding 
lstm_model.add(Embedding(input_dim=MAX_WORDS,output_dim=128,mask_zero=True))

# Dropout
lstm_model.add(SpatialDropout1D(0.2))

#LSTM MODEL
lstm_model.add(LSTM(units=64,dropout=0.2,recurrent_dropout=0.2))

#Hidden Layer
lstm_model.add(Dense(units=64,activation='relu'))

#Dropout
lstm_model.add(Dropout(0.3))

# Output Layer
lstm_model.add(Dense(units=1,activation='sigmoid'))

# %%
lstm_model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
lstm_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 16, 128)        │     3,200,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout1d_1             │ (None, 16, 128)        │             0 │
# │ (SpatialDropout1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,253,633 (12.41 MB)
#  Trainable params: 3,253,633 (12.41 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
lstm_history=lstm_model.fit(X_train_pad,y_train,validation_split=0.2,epochs=20,batch_size=64,verbose=1)
# Out:
# Epoch 1/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.7995 - loss: 0.4282 - val_accuracy: 0.8518 - val_loss: 0.3446
# Epoch 2/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9239 - loss: 0.1990 - val_accuracy: 0.8408 - val_loss: 0.3954
# Epoch 3/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 53ms/step - accuracy: 0.9654 - loss: 0.0987 - val_accuracy: 0.8399 - val_loss: 0.4813
# Epoch 4/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.9861 - loss: 0.0417 - val_accuracy: 0.8334 - val_loss: 0.6321
# Epoch 5/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9924 - loss: 0.0251 - val_accuracy: 0.8332 - val_loss: 0.6726
# Epoch 6/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 51ms/step - accuracy: 0.9952 - loss: 0.0147 - val_accuracy: 0.8345 - val_loss: 0.8413
# Epoch 7/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9965 - loss: 0.0108 - val_accuracy: 0.8336 - val_loss: 0.9506
# Epoch 8/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 53ms/step - accuracy: 0.9963 - loss: 0.0117 - val_accuracy: 0.8292 - val_loss: 0.8112
# Epoch 9/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9979 - loss: 0.0085 - val_accuracy: 0.8321 - val_loss: 0.9932
# Epoch 10/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 51ms/step - accuracy: 0.9986 - loss: 0.0045 - val_accuracy: 0.8321 - val_loss: 1.1053
# Epoch 11/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 16s 55ms/step - accuracy: 0.9988 - loss: 0.0041 - val_accuracy: 0.8305 - val_loss: 1.1781
# Epoch 12/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 52ms/step - accuracy: 0.9974 - loss: 0.0074 - val_accuracy: 0.8222 - val_loss: 1.1108
# Epoch 13/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 53ms/step - accuracy: 0.9975 - loss: 0.0077 - val_accuracy: 0.8200 - val_loss: 1.1234
# Epoch 14/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 52ms/step - accuracy: 0.9981 - loss: 0.0054 - val_accuracy: 0.8242 - val_loss: 1.1245
# Epoch 15/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 53ms/step - accuracy: 0.9992 - loss: 0.0025 - val_accuracy: 0.8305 - val_loss: 1.2068
# Epoch 16/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 53ms/step - accuracy: 0.9992 - loss: 0.0027 - val_accuracy: 0.8248 - val_loss: 1.3261
# Epoch 17/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9991 - loss: 0.0026 - val_accuracy: 0.8253 - val_loss: 1.3109
# Epoch 18/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 53ms/step - accuracy: 0.9985 - loss: 0.0043 - val_accuracy: 0.8248 - val_loss: 1.2009
# Epoch 19/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9991 - loss: 0.0029 - val_accuracy: 0.8270 - val_loss: 1.2849
# Epoch 20/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 53ms/step - accuracy: 0.9986 - loss: 0.0040 - val_accuracy: 0.8228 - val_loss: 1.1160

# %%
lstm_result=evaluation_model(lstm_model,"Simple-LSTM",X_test_pad,X_train_pad,y_test,y_train)
results1.append(lstm_result)
# Out:
# MODEL :Simple-LSTM
# TEST_ACCURACY:0.8306
# TRAIN_ACCURACY:0.9644
# RECALL :0.8355
#
# Classification_Report
#
#               precision    recall  f1-score   support
#
#            0     0.8471    0.8261    0.8364      2990
#            1     0.8133    0.8355    0.8242      2711
#
#     accuracy                         0.8306      5701
#    macro avg     0.8302    0.8308    0.8303      5701
# weighted avg     0.8310    0.8306    0.8306      5701

# %%
#Training Accurcay VS VALIDATION ACCURACY GRAPH
plt.figure(figsize=(8, 5))

plt.plot(lstm_history.history["accuracy"],label="Training Accuracy")
plt.plot(lstm_history.history["val_accuracy"],label="Validation Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.title("LSTM - Training vs Validation Accuracy")

plt.legend()
plt.grid()

plt.show()

# %%
#Training loss VS VALIDATION loss GRAPH 

plt.figure(figsize=(8,5))

plt.plot(rnn_history.history["loss"],label="Training_Loss")
plt.plot(rnn_history.history["val_loss"],label="Validation_loss")
plt.xlabel("Epoch")
plt.ylabel("loss")
plt.title("SIMPLE RNN-TRAINING LOSS VS VALIDATION LOSS")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### 3. GRU

# %%
#Sequential
gru_model=Sequential()

#Input 
gru_model.add(Input(shape=(MAX_LEN,)))

#Embedding Layer
gru_model.add(Embedding(input_dim=MAX_WORDS,output_dim=128,mask_zero=True))

#dropout layer
gru_model.add(SpatialDropout1D(0.2))

#Model
gru_model.add(LSTM(units=24,dropout=0.2,recurrent_dropout=0.3))

#Hidden Layer
gru_model.add(Dense(units=34,activation='relu'))

#Dropout
gru_model.add(Dropout(0.3))

# Output

gru_model.add(Dense(units=1,activation='sigmoid'))

# %%
gru_model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
gru_model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ (None, 16, 128)        │     3,200,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout1d_2             │ (None, 16, 128)        │             0 │
# │ (SpatialDropout1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 24)             │        14,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 34)             │           850 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 34)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            35 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,215,573 (12.27 MB)
#  Trainable params: 3,215,573 (12.27 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
gru_history=gru_model.fit(X_train_pad,y_train,validation_split=0.2,epochs=20,batch_size=64,verbose=1)
# Out:
# Epoch 1/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - accuracy: 0.7832 - loss: 0.4506 - val_accuracy: 0.8454 - val_loss: 0.3476
# Epoch 2/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9195 - loss: 0.2158 - val_accuracy: 0.8428 - val_loss: 0.3789
# Epoch 3/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9631 - loss: 0.1079 - val_accuracy: 0.8336 - val_loss: 0.4888
# Epoch 4/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9799 - loss: 0.0597 - val_accuracy: 0.8351 - val_loss: 0.5614
# Epoch 5/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9885 - loss: 0.0355 - val_accuracy: 0.8281 - val_loss: 0.6674
# Epoch 6/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9922 - loss: 0.0257 - val_accuracy: 0.8299 - val_loss: 0.7609
# Epoch 7/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9946 - loss: 0.0170 - val_accuracy: 0.8301 - val_loss: 0.8807
# Epoch 8/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9951 - loss: 0.0146 - val_accuracy: 0.8299 - val_loss: 0.9601
# Epoch 9/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 16s 55ms/step - accuracy: 0.9963 - loss: 0.0106 - val_accuracy: 0.8226 - val_loss: 1.0136
# Epoch 10/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9974 - loss: 0.0089 - val_accuracy: 0.8224 - val_loss: 1.0765
# Epoch 11/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9971 - loss: 0.0087 - val_accuracy: 0.8244 - val_loss: 1.0738
# Epoch 12/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 16s 55ms/step - accuracy: 0.9974 - loss: 0.0075 - val_accuracy: 0.8283 - val_loss: 1.1771
# Epoch 13/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 53ms/step - accuracy: 0.9988 - loss: 0.0034 - val_accuracy: 0.8233 - val_loss: 1.1804
# Epoch 14/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9985 - loss: 0.0047 - val_accuracy: 0.8200 - val_loss: 1.1709
# Epoch 15/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9990 - loss: 0.0040 - val_accuracy: 0.8255 - val_loss: 1.3399
# Epoch 16/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 51ms/step - accuracy: 0.9985 - loss: 0.0051 - val_accuracy: 0.8242 - val_loss: 1.1425
# Epoch 17/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9992 - loss: 0.0034 - val_accuracy: 0.8244 - val_loss: 1.3792
# Epoch 18/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.9985 - loss: 0.0058 - val_accuracy: 0.8255 - val_loss: 1.2307
# Epoch 19/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step - accuracy: 0.9993 - loss: 0.0023 - val_accuracy: 0.8226 - val_loss: 1.3538
# Epoch 20/20
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.8283 - val_loss: 1.5066

# %%
gru_result=evaluation_model(gru_model,"Simple-GRU",X_test_pad,X_train_pad,y_test,y_train)
results1.append(gru_result)
# Out:
# MODEL :Simple-GRU
# TEST_ACCURACY:0.8353
# TRAIN_ACCURACY:0.9656
# RECALL :0.8296
#
# Classification_Report
#
#               precision    recall  f1-score   support
#
#            0     0.8447    0.8405    0.8426      2990
#            1     0.8250    0.8296    0.8273      2711
#
#     accuracy                         0.8353      5701
#    macro avg     0.8349    0.8350    0.8349      5701
# weighted avg     0.8353    0.8353    0.8353      5701

# %%
#Training Accurcay VS VALIDATION ACCURACY GRAPH
plt.figure(figsize=(8, 5))

plt.plot(gru_history.history["accuracy"],label="Training Accuracy")
plt.plot(gru_history.history["val_accuracy"],label="Validation Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.title("LSTM - Training vs Validation Accuracy")

plt.legend()
plt.grid()

plt.show()

# %%
#Training loss VS VALIDATION loss GRAPH 

plt.figure(figsize=(8,5))

plt.plot(gru_history.history["loss"],label="Training_Loss")
plt.plot(gru_history.history["val_loss"],label="Validation_loss")
plt.xlabel("Epoch")
plt.ylabel("loss")
plt.title("SIMPLE RNN-TRAINING LOSS VS VALIDATION LOSS")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### 4. BI DIRECTIONAL RNN
